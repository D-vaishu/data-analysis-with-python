# %%
from matplotlib import pyplot as plt
x=[1,2,3,4]
y=[34,6,78,8]
plt.plot(x,y)#line grapy
plt.title("plot")
plt.xlabel('x values')
plt.ylabel('y values')
#title,lables,legends color,width,marker.
# Out:
# Text(0, 0.5, 'y values')

# %%
#there are 5 subjects psychology,nano technology, medicine,analocology,antopology two students are applied to do masters in any of these 5 studies
#witha lined show in which field  they can excel the cutoff is 70
from matplotlib import pyplot as plt

x1=["psy","nano","med","onc","ana"]
y1=[67,45,73,71,57]
z1=[43,67,68,53,85]
cut=[70,70,70,70,70]
plt.plot(x1,y1,label="y1",color='r',linestyle=':')
plt.plot(x1,z1,label="z1",marker="H")#line grapy
plt.plot(x1,cut,label="cut",color='k',marker="p",linewidth=2)
plt.xlabel('subjects')
plt.ylabel('marks')
plt.legend()

# %%
# an india vs australia  match  is on live india has given 298 as target for australia the runs for every 5 overs is guven as follows
a=[25,51,84,131,160,189,220,250,267,297]
#austarila has completion_ 25 overs
b=[15,41,94,110,151]
#plot overs vs runs for both the compires the india as blue line and austraila as yellow linegive with required label and lagned the
#marker for india is flag, the marker for is plus.take overs from a range function create runs as arrays.
import numpy as np
oo=np.arange(5,51,5)
rr=np.arange(5,26,5)
india=np.array([25,51,84,131,160,189,220,250,267,297])
australia=np.array([15,41,94,110,151])
plt.title("India vs Australia")
plt.plot( oo,india,label="india",color='b',marker='<')
plt.plot( rr,australia,label="australia", color='y',marker="p")
plt.xlabel('overs')
plt.ylabel('runs')
plt.legend()
plt.grid()
