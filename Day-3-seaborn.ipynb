# %%
import pandas as pd

# %%
# loading the file
df=pd.read_csv("/content/df.csv")
df
# Out:
#     Unnamed: 0   Names Initials  SEM1  SEM2  SEM3 Grade  Placed    average
# 0            0     Joe        K   9.8  10.0   9.9    A+       1  23.100000
# 1            1  Rajesh        M   8.9   9.1   9.3     A       1  21.100000
# 2            2  Kissan        V   9.9   9.8  10.0     A       0  23.033333
# 3            3    Mary        N   7.7   8.0   NaN     B       0        NaN
# 4            4    Jeen        K   9.8   9.1   9.9    A+       1  22.200000
# 5            5     Raj        M   8.9   9.1   9.3     A       1  21.100000
# 6            6  Hassan        V   9.9   9.0   9.2     A       1  21.966667
# 7            7    Mari        N   7.7   8.0   7.1     B       1  18.066667
# 8            8    Jess        K   NaN   9.1   9.9    A+       1        NaN
# 9            9  Rajini        M   NaN   9.1   9.3     A       0        NaN
# 10          10   Kiran        V   NaN   9.3   9.2     A       0        NaN
# ...

# %%
import seaborn as sns
#seaborn for importing the visulaization

# %%
import seaborn as sns
pl=sns.lineplot(x='Names',y='SEM1',data=df)

# %%
import pandas as pd
import seaborn as sns
sns.relplot(data=df,x="SEM1",y="Names",col="Placed")

# %%
import seaborn as sns

# %%
#create a replational plot using age as y axis index as x axis separated by class

diax=pd.read_excel("/content/diabetes.xlsx")
diax.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
diax['Index']=range(1,769)
sns.relplot(data=diax,x='Index',y='age',col='class')

# %%
tips=sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue="smoker")#hue=creating difference based on col via colors

# %% [markdown]
# load_dataset

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue="smoker",style='time',palette='dark')#hue=creating difference based on col via color

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='size')

# %%
#dowjones
dj=dowjones=sns.load_dataset("dowjones")
dj
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
dj.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dj, x="Date",y="Price",kind="line")

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
sns.relplot(data=fmri,x='timepoint',y='signal')

# %%
sns.catplot(data=tips,x='total_bill',y='day')
#category plot  based on

# %%
sns.catplot(data=tips,x='total_bill',y='smoker')

# %%
sns.catplot(data=tips,x='smoker',y='total_bill')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='violin')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='violin',hue='smoker')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='box',hue='smoker')

# %%
sns.catplot(data=tips,y='total_bill',x='time',kind='box')
