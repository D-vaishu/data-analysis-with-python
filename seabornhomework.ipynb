# %%
import pandas as pd

# %%
df=pd.read_csv("/content/data[1].csv",encoding='latin1' )
df
# Out:
#       stn_code       sampling_date           state   location agency  \
# 0        150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1        151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2        152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3        150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4        151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# ...        ...                 ...             ...        ...    ...
# 9197       NaN           26/4/2009  Andhra Pradesh  Hyderabad    NaN
# 9198       NaN           28/4/2009  Andhra Pradesh  Hyderabad    NaN
# 9199       NaN            5/4/2009  Andhra Pradesh  Hyderabad    NaN
# 9200       NaN            5/8/2009  Andhra Pradesh  Hyderabad    NaN
# 9201       NaN           5/10/2009  Andhra Pradesh  Hyderabad    NaN
#
#                                     type  so2   no2   rspm    spm  \
# 0     Residential, Rural and other Areas  4.8  17.4    NaN    NaN
# 1                        Industrial Area  3.1   7.0    NaN    NaN
# 2     Residential, Rural and other Areas  6.2  28.5    NaN    NaN
# 3     Residential, Rural and other Areas  6.3  14.7    NaN    NaN
# 4                        Industrial Area  4.7   7.5    NaN    NaN
# ...                                  ...  ...   ...    ...    ...
# 9197                    Industrial Areas  5.5  25.8  111.0  319.0
# 9198                    Industrial Areas  5.1  26.7  111.0  328.0
# 9199                    Industrial Areas  5.2  26.5  116.0  342.0
# 9200                    Industrial Areas  5.1  26.6  119.0  336.0
# 9201                             Industr  NaN   NaN    NaN    NaN
#
#      location_monitoring_station  pm2_5        date
# 0                            NaN    NaN  1990-02-01
# 1                            NaN    NaN  1990-02-01
# 2                            NaN    NaN  1990-02-01
# 3                            NaN    NaN  1990-03-01
# 4                            NaN    NaN  1990-03-01
# ...                          ...    ...         ...
# 9197                       Uppal    NaN  2009-04-26
# 9198                       Uppal    NaN  2009-04-28
# 9199                       Uppal    NaN  2009-04-05
# 9200                       Uppal    NaN  2009-08-05
# 9201                         NaN    NaN         NaN
#
# [9202 rows x 13 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(df.columns)
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    stn_code       sampling_date           state   location agency  \
# 0     150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1     151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2     152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3     150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4     151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# 3                         NaN    NaN  1990-03-01
# 4                         NaN    NaN  1990-03-01

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=(3, 4))
data=df[df['state'] =='Goa']
plt.title('Distribution of Air Pollutants in Goa')

sns.barplot(x="location", y="no2", data=data,hue="location")
# Out:
# <Axes: title={'center': 'Distribution of Air Pollutants in Goa'}>
