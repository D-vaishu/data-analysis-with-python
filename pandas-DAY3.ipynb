# %%
#importing panndas
import pandas as pd

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#series indexs of
#pd.series
a=['vai','khaleel','vaileel','priya','siri','sipivi']
b=['vaishu','kowsi','anitha','udaya','bhavya','varshi']
pd.Series(a,b)
# Out:
# vaishu        vai
# kowsi     khaleel
# anitha    vaileel
# udaya       priya
# bhavya       siri
# varshi     sipivi
# dtype: object

# %%
a=['vai','khaleel','vaileel','priya','siri','sipivi']
b=[1,2,3,4,5,6]
pd.Series(a,b)#one column acts as index and another colum act as value
# Out:
# 1        vai
# 2    khaleel
# 3    vaileel
# 4      priya
# 5       siri
# 6     sipivi
# dtype: object

# %%
# loading the file
dia=pd.read_csv("/content/diabetcsv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %% [markdown]
# #loading

# %%
grade=pd.read_csv("/content/grades.txt")
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade
# 0                  Joe K 9.8 10 9.9 A+
# 1               Rajesh M 8.9 9.1 9.3 A
# 2               Kissan V 9.9 9.3 9.2 A
# 3                   Mary N 7.7 8 7.1 B
# 4                Jeen K 9.8 9.1 9.9 A+
# 5                  Raj M 8.9 9.1 9.3 A
# 6                 Hassan V 9.9 9 9.2 A
# 7                   Mari N 7.7 8 7.1 B
# 8                Jess K 9.8 9.1 9.9 A+
# 9                 Rajini M 7 9.1 9.3 A
# 10               Kiran V 9.9 9.3 9.2 A
# 11                  Maya N 7.7 8 7.1 B
# 12              Jolin K 9.8 9.1 9.9 A+
# 13                  Riya M 8 9.1 9.3 A
# 14                Sana V 9.9 9.3 9.2 A
# 15                    Mark N 7.7 8 7 B

# %%
grade=pd.read_csv("/content/grades_withnulls.txt",sep")
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
diax=pd.read_excel("/content/diabetes.xlsx")
diax
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
demo=pd.read_csv("/content/demodt.txt")
demo
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diax1=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora")
diax1
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
#describe
diax1.describe()#describing a data frame
# Out:
#        Dead Alive
# count     5     5
# unique    1     1
# top     yes    no
# freq      5     5

# %%
demo.describe()
# Out:
#         Literacy  Cleanliness  Crime_Rate       Good
# count  26.000000    26.000000   26.000000  26.000000
# mean   75.269231    77.038462   52.307692   0.423077
# std    12.078270     8.879103    6.208183   0.503831
# min    55.000000    63.000000   41.000000   0.000000
# 25%    67.250000    69.250000   47.250000   0.000000
# 50%    75.500000    77.500000   52.000000   0.000000
# 75%    84.750000    83.750000   57.000000   1.000000
# max    94.000000    92.000000   63.000000   1.000000

# %%
grade.describe()
# Out:
#        Names Initials SEM1 SEM2 SEM3 Grade Placed
# count                                          17
# unique                                         17
# top                         Joe K 9.8 10 9.9 A+ 1
# freq                                            1

# %%
#shape of the column
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (17, 7)
# 17
# 7

# %%
#nan-->true
#syntax.isnull
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
#.sum()
print(df.sum())
# Out:
# Names       JoeRajeshKissanMaryJeenRajHassanMariJessRajini...
# Initials                                    KMVNKMVNKMVNKMMVN
# SEM1                                                    125.9
# SEM2                                                    153.0
# SEM3                                                    145.6
# Grade                                   A+AABA+AABA+AABA+AAAB
# Placed                                                     10
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df.dropna(inplace=True)#we are using inpllace =true to change the place
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
df.dropna()#dropna is used to remove nullvalue rows
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df
df.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
df1
print(df1.dropna(inplace=True))
# Out:
# None

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.isnull()
df2.fillna(555)
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %% [markdown]
# to cleainig the data :
# 2 types
# deleting the null
# creating the new data or change it

# %%
mdf=pd.read_csv("/content/grades_withnulls.csv")
mdf
mdf.fillna(444)
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  444.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  444.0   9.1    9.9    A+       1
# 9   Rajini        M  444.0   9.1    9.3     A       0
# 10   Kiran        V  444.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True)#new DataFrame object unless the inplace parameter is set to True, in that case the fillna () method does the replacing in the original DataFrame instead.
# Syntax dataframe .fillna (value, method, axis, inplace, limit, downcast) Parameters


df2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df2['SEM1'].mean()
#df2.fillna(555,inplace=True)
print(mv)
# Out:
# 8.992857142857144

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df2['SEM1'].mean()
df2.fillna(mv,inplace=True)
print(mv)
df2
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#loc=integer location,index
#loc=field names ,index
#dfname.loc=[index]-->
#dfname.loc[st:stop]-->range of rows
#dfname.loc[roww_index,col_name]-->row&col
df.loc[0]#access a particular cell in the given Pandas Dataframeusing the index and column labels. We are then selecting a single row and column by label using loc[].
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
df.loc[0:5]#to access the first 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
df.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
df.loc[8:5]
# Out:
# Empty DataFrame
# Columns: [Names, Initials, SEM1, SEM2, SEM3, Grade, Placed]
# Index: []

# %%
df.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
df.iloc[10:2,0:2]#both rows&col-->index
# Out:
# Empty DataFrame
# Columns: [Names, Initials]
# Index: []

# %%
#print the records who scores 9.3
#df[ df.SEM2==9.1]
#df[ df.SEM3==9.3]
df[df.SEM1==9.8]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 12  Jolin        K   9.8   9.1   9.9    A+       1

# %%
#print the names of the students who scored more than 9.8.
df.loc[df['SEM1']>9.8,"Names"]
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
print(df[df.index==1])
print(df.loc[df.index==1,"Grade"])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 1    A
# Name: Grade, dtype: object

# %%
#to access the grades of students scored more than 9 in sem1

df.loc[df['SEM3']>9,"Grade"]#access the records with sem>9 but printing only grade column
# Out:
# 0     A+
# 1      A
# 2      A
# 4     A+
# 5      A
# 6      A
# 8     A+
# 9      A
# 10     A
# 12    A+
# 13     A
# 14     A
# 15     A
# Name: Grade, dtype: object

# %%
df.drop_duplicates()#to delete the duplicate values
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.drop_duplicates(inplace=True)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.drop_duplicates(inplace=False)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.tail()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
#printing one row
#accesing using index fun
print(df[df.index==1])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
df.head()
df.head(14)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1

# %%
df.tail(7)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#column name
df5=df.columns
print(df5)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
collist=list(df.columns)
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
 #rename
 df.rename(columns={'Grade':"GPA"},inplace=True)
 df.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
#creating a new column
#dfname['new col]=values
df["conduct"]="good"
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed conduct
# 0      Joe        K   9.8  10.0   9.9  A+       1    good
# 1   Rajesh        M   8.9   9.1   9.3   A       1    good
# 2   Kissan        V   9.9   9.8  10.0   A       0    good
# 3     Mary        N   7.7   8.0   NaN   B       0    good
# 4     Jeen        K   9.8   9.1   9.9  A+       1    good
# 5      Raj        M   8.9   9.1   9.3   A       1    good
# 6   Hassan        V   9.9   9.0   9.2   A       1    good
# 7     Mari        N   7.7   8.0   7.1   B       1    good
# 8     Jess        K   NaN   9.1   9.9  A+       1    good
# 9   Rajini        M   NaN   9.1   9.3   A       0    good
# 10   Kiran        V   NaN   9.3   9.2   A       0    good
# 11    Maya        N   7.7   8.0   7.1   B       0    good
# 12   Jolin        K   9.8   9.1   9.9  A+       1    good
# 14    Riya        M   9.3   9.9  10.0   A       1    good
# 15    Sana        V   9.9   9.3   9.2   A       0    good
# ...

# %%
#create a new column average to print the average values of sem 1 and sem2 and sem3
df["average"]=(df['SEM1'])+(df['SEM2'])+(df['SEM3'])/3
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed    average
# 0      Joe        K   9.8  10.0   9.9    A+       1  23.100000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  21.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  23.033333
# 3     Mary        N   7.7   8.0   NaN     B       0        NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1  22.200000
# 5      Raj        M   8.9   9.1   9.3     A       1  21.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  21.966667
# 7     Mari        N   7.7   8.0   7.1     B       1  18.066667
# 8     Jess        K   NaN   9.1   9.9    A+       1        NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0        NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0        NaN
# 11    Maya        N   7.7   8.0   7.1     B       0  18.066667
# 12   Jolin        K   9.8   9.1   9.9    A+       1  22.200000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  21.100000
# ...

# %%
df['SEM1'].plot.line()
# Out:
# <Axes: >

# %%
df[['SEM1','SEM2']].plot.line()#ploting multiple columns
# Out:
# <Axes: >

# %%
df[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind="scatter",x="average",y="Names")
# Out:
# <Axes: xlabel='average', ylabel='Names'>

# %%
df.plot(kind="hist",x="average",y="SEM1")#y-axis is numeric
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="hist",x="Names",y="average")#
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("df.csv")#dfname.to_csv("dfname.csv")
